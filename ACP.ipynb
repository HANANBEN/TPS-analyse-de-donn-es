# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Automobile_data.csv')

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data=data[['highway-mpg','engine-size','horsepower','curb-weight','price']]

# %%
data.head()
# Out:
#    highway-mpg  engine-size horsepower  curb-weight  price
# 0           27          130        111         2548  13495
# 1           27          130        111         2548  16500
# 2           26          152        154         2823  16500
# 3           30          109        102         2337  13950
# 4           22          136        115         2824  17450

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [205 rows x 5 columns]

# %%
data.dropna(inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\339833404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace = True)

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [205 rows x 5 columns]

# %%
for x,row in data.iterrows():
    if row['highway-mpg']=='?':
        data.drop(x,inplace=True)

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [205 rows x 5 columns]

# %%
for x,row in data.iterrows():
    if row['engine-size']=='?':
        data.drop(x,inplace=True)

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [205 rows x 5 columns]

# %%
for x,row in data.iterrows():
    if row['horsepower']=='?':
        data.drop(x,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\865080669.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(x,inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\865080669.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(x,inplace=True)

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [203 rows x 5 columns]

# %%
for x,row in data.iterrows():
    if row['curb-weight']=='?':
        data.drop(x,inplace=True)

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [203 rows x 5 columns]

# %%
for x,row in data.iterrows():
    if row['price']=='?':
        data.drop(x,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\236972867.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(x,inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\236972867.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(x,inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\236972867.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(x,inplace=True)
# ...

# %%
data
# Out:
#      highway-mpg  engine-size horsepower  curb-weight  price
# 0             27          130        111         2548  13495
# 1             27          130        111         2548  16500
# 2             26          152        154         2823  16500
# 3             30          109        102         2337  13950
# 4             22          136        115         2824  17450
# ..           ...          ...        ...          ...    ...
# 200           28          141        114         2952  16845
# 201           25          141        160         3049  19045
# 202           23          173        134         3012  21485
# 203           27          145        106         3217  22470
# 204           25          141        114         3062  22625
#
# [199 rows x 5 columns]

# %%
# !pip install -U scikit-learn

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
standardized_data = scaler.fit_transform(data)
standardized_data = pd.DataFrame(standardized_data, columns=data.columns)

# %%
standardized_data
# Out:
#      highway-mpg  engine-size  horsepower  curb-weight     price
# 0      -0.539128     0.076255    0.202967    -0.015486  0.031609
# 1      -0.539128     0.076255    0.202967    -0.015486  0.409187
# 2      -0.685494     0.604493    1.350877     0.514841  0.409187
# 3      -0.100029    -0.427972   -0.037293    -0.422391  0.088780
# 4      -1.270959     0.220320    0.309749     0.516770  0.528554
# ..           ...          ...         ...          ...       ...
# 194    -0.392762     0.340374    0.283054     0.763613  0.452536
# 195    -0.831860     0.340374    1.511051     0.950674  0.728965
# 196    -1.124592     1.108721    0.816966     0.879321  1.035550
# 197    -0.539128     0.436418    0.069489     1.274656  1.159315
# 198    -0.831860     0.340374    0.283054     0.975744  1.178791
#
# [199 rows x 5 columns]

# %%
moyennes=np.mean(standardized_data,axis=0)

# %%
print(moyennes)
# Out:
# highway-mpg    2.231604e-16
# engine-size    4.240048e-17
# horsepower     9.819058e-17
# curb-weight    9.819058e-17
# price         -1.071170e-16
# dtype: float64

# %%
ecart_types = np.std(data, axis=0)
print(ecart_types)
# Out:
# highway-mpg      6.832179
# engine-size     41.647893
# curb-weight    518.547730
# dtype: float64
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\fromnumeric.py:3603: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
standardized_data1=standardized_data[["highway-mpg","engine-size","horsepower","curb-weight"]]
standardized_data1
# Out:
#      highway-mpg  engine-size  horsepower  curb-weight
# 0      -0.539128     0.076255    0.202967    -0.015486
# 1      -0.539128     0.076255    0.202967    -0.015486
# 2      -0.685494     0.604493    1.350877     0.514841
# 3      -0.100029    -0.427972   -0.037293    -0.422391
# 4      -1.270959     0.220320    0.309749     0.516770
# ..           ...          ...         ...          ...
# 194    -0.392762     0.340374    0.283054     0.763613
# 195    -0.831860     0.340374    1.511051     0.950674
# 196    -1.124592     1.108721    0.816966     0.879321
# 197    -0.539128     0.436418    0.069489     1.274656
# 198    -0.831860     0.340374    0.283054     0.975744
#
# [199 rows x 4 columns]

# %%
corr_matrix = standardized_data1.corr()

# %%
print(corr_matrix)
# Out:
#              highway-mpg  engine-size  horsepower  curb-weight
# highway-mpg     1.000000    -0.679688   -0.804596    -0.794937
# engine-size    -0.679688     1.000000    0.822713     0.849301
# horsepower     -0.804596     0.822713    1.000000     0.758063
# curb-weight    -0.794937     0.849301    0.758063     1.000000

# %%
corr_matrix
# Out:
#              highway-mpg  engine-size  horsepower  curb-weight
# highway-mpg     1.000000    -0.679688   -0.804596    -0.794937
# engine-size    -0.679688     1.000000    0.822713     0.849301
# horsepower     -0.804596     0.822713    1.000000     0.758063
# curb-weight    -0.794937     0.849301    0.758063     1.000000

# %%
eig_vals,eig_vecs = np.linalg.eig(corr_matrix)

# %%
print(eig_vals)
# Out:
# [3.35535151 0.07957421 0.32633156 0.23874271]

# %%
print(eig_vecs)
# Out:
# [[-0.4878759   0.42548127  0.74219024 -0.17348324]
#  [ 0.4999754  -0.57849601  0.63617369 -0.10319881]
#  [ 0.50458528  0.45615445 -0.09956758 -0.72622525]
#  [ 0.5073415   0.52557699  0.18580359  0.6571533 ]]

# %%
# !pip install -U seaborn
# Out:
# ...
#                                               0.0/293.3 kB ? eta -:--:--
#      ---------                               71.7/293.3 kB 2.0 MB/s eta 0:00:01
#      ------------------------------         235.5/293.3 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
principalcomponents=pca.fit_transform(corr_matrix)
principalDf=pd.DataFrame(data=principalcomponents,columns=['PC1','PC2'])
principalDf
# Out:
#         PC1       PC2
# 0  2.499148  0.000015
# 1 -0.813574 -0.044629
# 2 -0.839089  0.191896
# 3 -0.846485 -0.147281

# %%
# !pip install -U matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = principalDf.iloc[:, 0]
y = principalDf.iloc[:, 1]
plt.scatter(x, y)
plt.title("Nuage de points")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
# !pip install -U seaborn

# %%
import seaborn as sns

# %%
principalDf['price']=standardized_data[["price"]]
sns.scatterplot(x="PC1", y="PC2", hue="price", data=principalDf)
plt.title("Nuage de points avec price comme hue")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
def correlation_graph(pca, 
                      x_y, 
                      features) : 
    x,y=x_y
    fig, ax = plt.subplots(figsize=(10, 9))
    for i in range(0, pca.components_.shape[1]):
        ax.arrow(0,0, 
                pca.components_[x, i],  
                pca.components_[y, i],  
                head_width=0.07,
                head_length=0.07, 
                width=0.02, )
        plt.text(pca.components_[x, i] + 0.05,
                pca.components_[y, i] + 0.05,
                features[i])
    plt.plot([-1, 1], [0, 0], color='grey', ls='--')
    plt.plot([0, 0], [-1, 1], color='grey', ls='--')
    plt.xlabel('F{} ({}%)'.format(x+1, round(100*pca.explained_variance_ratio_[x],1)))
    plt.ylabel('FC{} ({}%)'.format(y+1, round(100*pca.explained_variance_ratio_[y],1)))
    plt.title("Cercle des corrélations (F{} et F{})".format(x+1, y+1))
    an = np.linspace(0, 2 * np.pi, 100)
    plt.plot(np.cos(an), np.sin(an))
    plt.axis('equal')
    plt.show(block=False)

# %%
correlation_graph(pca,[0,1],['highway-mpg','engine-size','horsepower','curb-weight'])

# %%
for vehicule in range(4):
    for  axe in range(2): 
         qualite_representation = principalcomponents[vehicule, axe]
         print("Qualité de représentation de la vahicule", vehicule, "sur l'axe", axe, ":", qualite_representation)
# Out:
# Qualité de représentation de la vahicule 0 sur l'axe 0 : 2.499148408488431
# Qualité de représentation de la vahicule 0 sur l'axe 1 : 1.4829026820301766e-05
# Qualité de représentation de la vahicule 1 sur l'axe 0 : -0.8135742618253334
# Qualité de représentation de la vahicule 1 sur l'axe 1 : -0.04462936579612653
# Qualité de représentation de la vahicule 2 sur l'axe 0 : -0.8390893241545
# Qualité de représentation de la vahicule 2 sur l'axe 1 : 0.19189578557461687
# Qualité de représentation de la vahicule 3 sur l'axe 0 : -0.8464848225085974
# Qualité de représentation de la vahicule 3 sur l'axe 1 : -0.14728124880531104
